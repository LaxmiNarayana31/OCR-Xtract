# %% [markdown]
# <a href="https://colab.research.google.com/github/LaxmiNarayana31/OCR-Xtract/blob/main/ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch pillow numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from transformers import AutoModel, AutoTokenizer
import torch
from PIL import Image
import tempfile
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# !pip install tiktoken verovio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 106.5 MB/s eta 0:00:00
# ...

# %%
model_name = 'ucaslcl/GOT-OCR2_0'

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModel.from_pretrained(
    model_name,
    trust_remote_code=True,
    low_cpu_mem_usage=True,
    device_map="auto" if device.type == "cuda" else None,
    use_safetensors=True,
    pad_token_id=tokenizer.eos_token_id
).eval().to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/300 [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/9.47k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ucaslcl/GOT-OCR2_0:
# - tokenization_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# qwen.tiktoken:   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/149 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/986 [00:00<?, ?B/s]
# modeling_GOT.py:   0%|          | 0.00/33.8k [00:00<?, ?B/s]
# render_tools.py:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ucaslcl/GOT-OCR2_0:
# - render_tools.py
# ...

# %%
from google.colab import files

uploaded = files.upload()

# Get the uploaded file name
image_path = list(uploaded.keys())[0]
print(f"Uploaded image: {image_path}")
# Out:
#      <input type="file" id="files-2b86778a-1262-4866-92cd-bcd195c0b102" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b86778a-1262-4866-92cd-bcd195c0b102">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def process_image(image_path):
    image = Image.open(image_path)
    with tempfile.NamedTemporaryFile(suffix=".png", delete=False) as tmp_file:
        image.save(tmp_file.name)
        return tmp_file.name

# %%
import warnings
import logging
import logging

# Suppressing all warnings
warnings.filterwarnings("ignore")
logging.getLogger("transformers").setLevel(logging.ERROR)

# %%
def perform_ocr(image_path):
    processed_image_path = process_image(image_path)
    inputs = tokenizer(processed_image_path, return_tensors="pt").to(device)
    ocr_result = model.chat(tokenizer, processed_image_path, ocr_type='ocr')
    return ocr_result.strip()

# %%
extracted_text = perform_ocr(image_path)
print(extracted_text)
# Out:
# PROJECTS
# • DocsQuery AI
# | Ω | Python, LangChain, Streamlit, Gemini API, FAISS
# – Designed an interactive UI for uploading PDFs and querying LLMs, handling 300+ daily user queries.
# – Chunked and indexed PDF documents into a FAISS vector database, enabling fast semantic search with a 50% improvement
# in search response times.
# – Used LangChain to query the database via Google Gemini API, delivering context-aware responses with 85% accuracy.
# • MovieSense
# | Ω | Python, Streamlit, Scikit-learn, Pandas, TMDB API
# – Built a content-based movie recommender system, utilizing tags (Genre, Cast, Crew, and Overview) to achieve 70%+
# accuracy in user recommendations.
# – Enables users to input a movie title and receive 5 similar movie recommendations with posters, IMDb ratings, trailers, and
# reviews.
# – Utilized cosine similarity to calculate movie similarity and generate recommendations.
# ...
